# %% [markdown]
# <a href="https://colab.research.google.com/github/MadhukumarMMK/ai-mentor-portfolio/blob/main/LabDay2A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Claude - Pattern 1
# https://claude.ai/share/16d0a43e-6c5e-4144-8ab2-df38c5a8da04
#
# Score - 4.5/5
#
# #Chatgpt - Pattern 1
# https://chatgpt.com/share/6a0e9ece-72f4-8320-93a9-6fe4f8c574ed
#
# Score - 5/5
#
# #Claude - Pattern 2
# https://claude.ai/share/5df1d1c4-3e23-4f7a-81c5-8189510028d0
#
# Score - 4.8
#
# #Chatgpt - Pattern 2
# https://chatgpt.com/share/6a0ea181-8d7c-8321-9532-2c58f7f74391
#
# Score - 4.7
#
# #Claude - Pattern 3
# https://claude.ai/share/dc9885f7-d84d-4ab3-9e4f-9144aa7ca1c1
#
# Score - 4.7
#
# #Chatgpt - Pattern 3
# https://chatgpt.com/share/6a0ea469-05cc-8321-a1b7-da9e3c7d4b97
#
# Score - 4.9
#
# #Claude - Pattern 4
# https://claude.ai/share/bc7085fd-8df4-485b-b2bf-93c1eda1b6c3
#
# Score - 4.8
#
# #Chatgpt - Pattern 4
# https://chatgpt.com/share/6a0ea4c2-240c-8324-b20e-2661292d62f1
#
# Score - 4.9/5
#
# #Claude - Pattern 5
# https://claude.ai/share/5ed3862e-aad2-48b3-bf04-bca8a22fd3a9
#
# Score - 5/5
#
# #Chatgpt - Pattern 5
# https://chatgpt.com/share/6a0ea523-d128-83a4-afc5-227cd5ad0890
#
# Score - 5/5
#
# #Claude - Pattern 6
# https://claude.ai/share/eda31702-4f93-4f4b-bd6e-2b33bdd98ce5
#
# Score - 4.9/5
#
# #Chatgpt - Pattern 6
# https://chatgpt.com/share/6a0ea673-41b8-8321-8d61-027213e49a6a
#
#
# #Pair-score
# | Criterion              | Score (0-2) | What You Check in the Prompt                                                                                                                              |
# | ---------------------- | ----------- | --------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Clarity                | 0-2         | Prompt asks for ONE clear goal like roadmap, logic-building, or consistency plan. Avoids confusing “do everything” instructions.                          |
# | Beginner Context       | 0-2         | Clearly mentions beginner students, B.Tech CSE audience, starting from zero, placement preparation, or learning struggles.                                |
# | Specificity            | 0-2         | Includes concrete requirements like daily schedule, coding exercises, logic-building methods, practice routines, consistency strategy, or 30-day roadmap. |
# | Output Structure       | 0-2         | Specifies output format clearly — JSON, step-by-step plan, weekly roadmap, tables, bullet points, or structured sections.                                 |
# | Practical Verification | 0-2         | Includes follow-up checks like beginner coding challenges, revision tasks, practice questions, progress tracking, or consistency measurement.             |
